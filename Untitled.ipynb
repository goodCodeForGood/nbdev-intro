# %%
import numpy as np
import pandas as pd

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
a*a
# Out:
# array([1, 4, 9])

# %%
np.dot(a,a) #vector multiplication; vectorized = bc
# Out:
# 14

# %%
dataset = pd.read_csv('movies.csv', encoding='utf-8')

# %%
dataset.drop(['color'], axis=1, inplace=True)

# %%
for i in dataset['director_name']: #not vectorized fns = can't do computation in parallel. doesn't use matrix operations.
    #so avoid using often
    print(i)
# Out:
# Martin Scorsese
# Shane Black
# Quentin Tarantino
# Kenneth Lonergan
# Peter Jackson
# nan
# Peter Jackson
# Edward Hall
# Joss Whedon
# Joss Whedon
# Tom Tykwer
# Null
# Christopher Spencer
# Christopher Nolan
# F. Gary Gray
# Richard Linklater
# Quentin Tarantino
# Michael Bay
# Christopher Nolan
# Peter Jackson
# Tom Hooper
# Tom Hooper
# Kathryn Bigelow
# Ridley Scott
# nan
# Michael Bay
# Denis Villeneuve
# Gnana Rajasekaran
# Marc Webb
# Nan
# Ridley Scott
# Ridley Scott
# nan
# Mike Leigh
# Gore Verbinski
# David Fincher
# Bryan Singer
# Jay Oliva
# Christopher Nolan
# Paul Thomas Anderson
# Sam Mendes
# nan
# Michael Patrick King
# Tate Taylor
# Francis Lawrence
# Steven Spielberg
# Michael Bay
# Guillaume Canet
# Paul Thomas Anderson
# Bryan Singer
# Adam McKay
# Zack Snyder
# Sam Mendes
# Sam Mendes
# Baz Luhrmann
# Baz Luhrmann
# nan
# Steven Spielberg
# Marc Webb
# nan
# Joss Whedon
# Timur Bekmambetov
# Timur Bekmambetov
# Timur Bekmambetov
# Justin Chadwick
# ...

# %%
dataset['director_name'].fillna('', inplace=True)

# %%
dataset
# Out:
#         director_name  duration        gross  \
# 0     Martin Scorsese       240  116866727.0
# 1         Shane Black       195  408992272.0
# 2   Quentin Tarantino       187   54116191.0
# 3    Kenneth Lonergan       186      46495.0
# 4       Peter Jackson       186  258355354.0
# ..                ...       ...          ...
# 94      Steve McQueen       134   56667870.0
# 95   Richard J. Lewis       134    7501404.0
# 96    Paul Greengrass       134  107100855.0
# 97         David Ayer       134   85707116.0
# 98     Clint Eastwood         5   47034272.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                  Drama                             Margaret
# ...
